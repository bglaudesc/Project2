# %%
import pandas as pd

# %%
csvinput_1 = "./Airline_Delay_cleaned.csv"
csvinput_2 = "./final_weather.csv"

# %%
csvoutput = "./Combined_Cleaned.csv"

# %%
df_1 = pd.read_csv (csvinput_1)
df_2 = pd.read_csv (csvinput_2)

# %%
df_1.head()
# Out:
#    month         City Air_code State                Airport  arr_flights  \
# 0      1     Aberdeen      ABR    SD      Aberdeen Regional         62.0
# 1      1      Abilene      ABI    TX       Abilene Regional         28.0
# 2      1  Adak Island      ADK    AK                   Adak          9.0
# 3      1    Aguadilla      BQN    PR       Rafael Hernandez        159.0
# 4      1        Akron      CAK    OH  Akron-Canton Regional        504.0
#
#    arr_del15  carrier_ct   weather_ct  nas_ct  security_ct  late_aircraft_ct  \
# 0        4.0        1.03         0.00    1.09          0.0              1.88
# 1        9.0        4.94         0.00    2.28          0.0              1.78
# 2        4.0        0.00         0.00    2.00          0.0              2.00
# 3       32.0       15.60         1.54    6.26          0.0              8.60
# 4       96.0       23.83         3.90   31.53          0.0             36.76
#
# ...

# %%
df_2.head()
# Out:
#    month  Cold   Fog  Hail  Precipitation  Rain  Snow  Storm  EventTotal  \
# 0      1   0.0  36.0   0.0            1.0  58.0   2.0    0.0          97
# 1      1   1.0  10.0   0.0            0.0   4.0  39.0    0.0          54
# 2      1   5.0  20.0   0.0            0.0  16.0  35.0    0.0          76
# 3      1   0.0   4.0   0.0            1.0   0.0  21.0    0.0          26
# 4      1  42.0  26.0   0.0            0.0   0.0  70.0    0.0         138
#
#    Avg_Severity  LocationLat  LocationLng      City      County State  ZipCode
# 0      2.072165      34.4917     -88.2011   Belmont  Tishomingo    MS  38827.0
# 1      1.555556      38.0972    -106.1689  Saguache    Saguache    CO  81149.0
# 2      1.815789      46.0244     -92.8991  Hinckley        Pine    MN  55037.0
# 3      1.923077      48.8844     -99.6208     Rolla     Rolette    ND  58367.0
# 4      2.275362      48.3008    -102.4064   Stanley   Mountrail    ND  58784.0

# %%
df_Combined = df_1.merge(df_2 , how="inner", on=["month", "City", "State"])
df_Combined
# Out:
#       month         City Air_code State                               Airport  \
# 0         1     Aberdeen      ABR    SD                     Aberdeen Regional
# 1         1      Abilene      ABI    TX                      Abilene Regional
# 2         1        Akron      CAK    OH                 Akron-Canton Regional
# 3         1       Albany      ABY    GA            Southwest Georgia Regional
# 4         1  Albuquerque      ABQ    NM     Albuquerque International Sunport
# ...     ...          ...      ...   ...                                   ...
# 3276     12      Wichita      ICT    KS  Wichita Dwight D Eisenhower National
# 3277     12    Williston      ISN    ND           Sloulin Field International
# 3278     12   Wilmington      ILM    NC              Wilmington International
# 3279     12    Worcester      ORH    MA                    Worcester Regional
# 3280     12         Yuma      YUM    AZ          Yuma MCAS/Yuma International
#
# ...

# %%
df_Combined.to_csv(csvoutput,index=False)
